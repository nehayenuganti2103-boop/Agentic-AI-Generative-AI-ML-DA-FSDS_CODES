# %% [markdown]
# # CONDITIONAL STATEMENTS

# %% [markdown]
# # -->if
# # -->else
# # -->nested if
# # -->if elif else

# %%
if True:
    print('Data Science')
# Out:
# Data Science

# %%
if False:
    print('Data Science')
print('Agentic AI & Generative AI')
# Out:
# Agentic AI & Generative AI

# %%
if True:
    print('Data Science')
print('Agentic AI & Generative AI')
# Out:
# Data Science
# Agentic AI & Generative AI

# %%
if True:
    print('Data Science')
else:
    print('Agentic AI & Generative AI')
# Out:
# Data Science

# %%
if False:
    print('Data Science')
else:
    print('Agentic AI & Generative AI')
# Out:
# Agentic AI & Generative AI

# %%
x = 4             #print even number 
r = x % 2

if r == 0:
    print('Even Number')
# Out:
# Even Number

# %%
x = 5
r = x % 2

if r!=0:
    print('Odd Number')
# Out:
# Odd Number

# %%
x = 7
r = x % 2

if r==1:
    print('Odd Number')
# Out:
# Odd Number

# %%
x = 5
r = x % 2

if r==0:
    print('Even Number')
print('Odd Number')
# Out:
# Odd Number

# %%
x = 4
r = x % 2

if r==0:
    print('Even Number')
print('Odd Number')
# Out:
# Even Number
# Odd Number

# %%
x = 9                                #multiple if statements
r = x % 2

if r==0:
    print('Even Number')

if r==1:
    print('Odd Number')
# Out:
# Odd Number

# %%
x = 8
r = x % 2

if r==0:
    print('Even Number')
else:
    print('Odd Number')
# Out:
# Even Number

# %%
x = 9
r = x % 2
if r!=0:
    print('Odd Number')
else:
    print('Even Number')
# Out:
# Odd Number

# %%
x = 3
r = x % 2

if r==0:
    print('Even Number')
    if x>5:
        print('Greater Number')
else:
    print('Odd Number')
# Out:
# Odd Number

# %%
x = 4
r = x % 2
if r==0:
    print('Even Number')
    if x>5:
        print('Greater Number')
else:
    print('Odd Number')
# Out:
# Even Number

# %%
x = 4
r = x % 2
if r==0:
    print('Even Number')
    if x>5:
        print('Greater Number')
    else:
        print('Lesser Number')
else:
    print('Odd Number')
# Out:
# Even Number
# Lesser Number

# %%
x = 13
r = x % 2

if r==0:
    print('Even Number')
    if x>5:
        print('Greater Number')
    else:
        print('Lesser Number')
else:
    print('Odd Number')
# Out:
# Odd Number

# %%
 x=3                      #multiple if statements
 if x==1:
     print('One')
 if x==2:
     print('Two')
 if x==3:
     print('Three')
 if x==4:
     print('Four')
# Out:
# Three

# %%
x =1
if x==1:
    print('One')
elif x==2:
    print('Two')
elif x==3:
    print('Three')
elif x==4:
    print('Four')
# Out:
# One

# %%
x=5
if x==1:
    print('One')
elif x==2:
    print('Two')
elif x==3:
    print('Three')
elif x==4:
    print('Four')
else:
    print('Number Not Found')
# Out:
# Number Not Found

# %% [markdown]
# # BASIC QUESTIONS

# %% [markdown]
# # 1.Odd or Even Checker

# %%
x=11
if x%2==0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Odd Number

# %%
user=int(input("Enter a number:"))
if user%2==0:
         print("Even Number")
else:
         print("Odd Number")
# Out:
# Enter a number: 24
# Even Number

# %% [markdown]
# # 2.Voting Eligibility

# %%
age=21
if age>=18:
    print("Eligible to vote",age)
else:
    print("Not Eligible to vote",age)
# Out:
# Eligible to vote 21

# %%
age=int(input("Enter the age:"))
if age>=18:
    print("Eligible to vote")
else:
    print("Not Eligible to vote")
# Out:
# Enter the age: 15
# Not Eligible to vote

# %% [markdown]
# # 3.Positive , Negative or Zero

# %%
user=int(input("choose a number between 0 and 1 and -1"))
if user==0:
    print("Entered number is zero",user)
elif user>0:
    print("Entered number is postive number",user)
elif user<0:
    print("Entered number is negative number",user)
# Out:
# choose a number between 0 and 1 and -1 -1
# Entered number is negative number -1

# %% [markdown]
# # 4.Leap Year Checker

# %%
year=int(input("Enter a year"))
if(year % 400 == 0) or (year % 4 == 0 and year % 100!=0):
    print("It's a leap year",year)
else:
    print("It's not a leap year",year)
# Out:
# Enter a year 2023
# It's not a leap year 2023

# %% [markdown]
# # 5.Password Strength Checker

# %%
password=input("Enter a password")
has_digit=True
has_special_char=True

special_char="!@#$%^&*()_+=-<>,./?;:'[{]}\|`~"
print("password",password)
# Out:
# Enter a password Neha@219
# password Neha@219

# %% [markdown]
# # 6.Discount Calculator

# %%
bill=float(input("enter the total bill"))
if bill>5000:
    discount=0.20*bill
elif bill>2000:
    discount=0.10*bill
else:
    discount=0
final_bill=bill- discount
print("Discount Applied:",discount)
print("Final Amount to pay :",final_bill)
# Out:
# enter the total bill 6890
# Discount Applied: 1378.0
# Final Amount to pay : 5512.0

# %% [markdown]
# # 7.Number Guessing Name

# %%
suspense=19
guess=int(input("Enter a number between 10 and 20:"))

if guess < 10 or guess > 20 :
    print("You are almost there !")
elif guess == suspense:
    print("Exactly")
else:
    print("You Tried Well ")
# Out:
# Enter a number between 10 and 20: 21
# You are almost there !
