# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r'C:\Users\Neha\OneDrive\Desktop\VSCode\OpenCV\image.jpeg')

# %%
input
# Out:
# array([[[ 70, 105,  79],
#         [ 72, 107,  81],
#         [ 74, 111,  85],
#         ...,
#         [ 37,  58,  73],
#         [ 34,  55,  70],
#         [ 35,  54,  69]],
#
#        [[ 72, 107,  81],
#         [ 74, 109,  83],
#         [ 76, 113,  87],
#         ...,
#         [ 38,  59,  74],
#         [ 35,  56,  71],
#         [ 36,  55,  70]],
#
#        [[ 73, 108,  82],
#         [ 75, 110,  84],
#         [ 77, 114,  88],
#         ...,
#         [ 39,  60,  75],
#         [ 37,  58,  73],
#         [ 39,  58,  73]],
#
#        ...,
#
#        [[ 35,  40,  85],
#         [ 34,  39,  84],
#         [ 35,  40,  85],
#         ...,
#         [ 39,  31,  42],
#         [ 39,  31,  41],
#         [ 38,  30,  41]],
#
#        [[ 33,  40,  83],
#         [ 33,  40,  83],
#         [ 34,  40,  85],
#         ...,
#         [ 40,  31,  41],
#         [ 39,  31,  38],
#         [ 38,  29,  39]],
#
#        [[ 33,  40,  83],
#         [ 32,  39,  82],
#         [ 34,  40,  85],
#         ...,
#         [ 40,  32,  39],
#         [ 39,  31,  38],
#         [ 38,  30,  37]]], dtype=uint8)

# %%
cv2.imshow('image',input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print('Height of Image:',int(input.shape[0]), 'pixels')
print('Width of Image:',int(input.shape[1]), 'pixels')
# Out:
# Height of Image: 750 pixels
# Width of Image: 797 pixels

# %%
cv2.imwrite('output.png',input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Neha\\OneDrive\\Desktop\\VSCode\\OpenCV'
