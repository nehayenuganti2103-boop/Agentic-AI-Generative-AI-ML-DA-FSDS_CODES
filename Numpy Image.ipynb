# %%
import numpy as np

# %%
import matplotlib.pyplot as plt    #visulatization

# %%
from PIL import Image              #pyhton image library

# %%
feature_image = Image.open(r'C:\Users\Neha\OneDrive\Desktop\Img.jpg')

# %%
feature_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=501x613>

# %%
print(type(feature_image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
fea_arr=np.asarray(feature_image)
fea_arr
# Out:
# array([[[  9,   9,   9],
#         [  8,   8,   8],
#         [  8,   8,   8],
#         ...,
#         [  9,   9,   9],
#         [  9,   9,   9],
#         [  9,   9,   9]],
#
#        [[ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         ...,
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29]],
#
#        [[ 25,  25,  25],
#         [ 25,  25,  25],
#         [ 25,  25,  25],
#         ...,
#         [ 25,  25,  25],
#         [ 25,  25,  25],
#         [ 25,  25,  25]],
#
#        ...,
#
#        [[ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         ...,
#         [ 32,  32,  34],
#         [ 32,  32,  34],
#         [ 32,  32,  34]],
#
#        [[  6,   6,   6],
#         [  7,   7,   7],
#         [  7,   7,   7],
#         ...,
#         [  5,   5,   7],
#         [  5,   5,   7],
#         [  5,   5,   7]],
#
#        [[126, 126, 126],
#         [126, 126, 126],
#         [126, 126, 126],
# ...

# %%
plt.imshow(fea_arr)
plt.show()

# %%
fea_arr.shape
# Out:
# (613, 501, 3)

# %%
myimage=Image.open(r'C:\Users\Neha\OneDrive\Desktop\Img1.jpg')
myimage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x888>

# %%
print(type(myimage))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
my_img=np.asarray(myimage)
my_img
# Out:
# array([[[165, 180, 235],
#         [165, 180, 235],
#         [165, 180, 235],
#         ...,
#         [164, 179, 234],
#         [165, 180, 235],
#         [165, 180, 235]],
#
#        [[165, 180, 235],
#         [165, 180, 235],
#         [165, 180, 235],
#         ...,
#         [164, 179, 234],
#         [165, 180, 235],
#         [165, 180, 235]],
#
#        [[165, 180, 235],
#         [165, 180, 235],
#         [164, 179, 234],
#         ...,
#         [164, 179, 234],
#         [165, 180, 235],
#         [165, 180, 235]],
#
#        ...,
#
#        [[160, 188, 236],
#         [160, 188, 236],
#         [160, 188, 236],
#         ...,
#         [160, 192, 239],
#         [160, 192, 239],
#         [161, 193, 240]],
#
#        [[160, 186, 235],
#         [160, 186, 235],
#         [160, 186, 235],
#         ...,
#         [159, 191, 238],
#         [160, 192, 239],
#         [160, 192, 239]],
#
#        [[160, 186, 235],
#         [160, 186, 235],
#         [160, 186, 235],
# ...

# %%
plt.imshow(myimage)
plt.show()

# %%
my_img.shape
# Out:
# (888, 500, 3)
