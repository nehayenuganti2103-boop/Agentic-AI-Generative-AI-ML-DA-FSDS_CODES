# %%
import numpy as np
print(np.__version__)
# Out:
# 2.1.3

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Neha'

# %%
movies = pd.read_csv(r"C:\Users\Neha\Downloads\AI\MovieRatings.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Zoner','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies
# Out:
#                       Film      Zoner  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Zoner           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.describe().transpose()
# Out:
#                 count         mean        std     min     25%     50%     75%  \
# CriticRating    559.0    47.309481  26.413091     0.0    25.0    46.0    70.0
# AudienceRating  559.0    58.744186  16.826887     0.0    47.0    58.0    72.0
# BudgetMillions  559.0    50.236136  48.731817     0.0    20.0    35.0    65.0
# Year            559.0  2009.152057   1.362632  2007.0  2008.0  2009.0  2010.0
#
#                    max
# CriticRating      97.0
# AudienceRating    96.0
# BudgetMillions   300.0
# Year            2011.0

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Zoner           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Zoner           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.head()
# Out:
#                     Film      Zoner  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Zoner           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Zoner = movies.Zoner.astype('category')
movies.Zoner
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Zoner, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Zoner           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.Year = movies.Year.astype('category')
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Zoner           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Zoner.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %% [markdown]
# ## VISULATIZATIONS USING SEABORN

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
movies
# Out:
#                       Film      Zoner  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating')
plt.show()

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='scatter')
plt.show()

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='hex')
plt.show()

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='reg')
plt.show()

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='kde')
plt.show()

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='hist')
plt.show()

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='resid')
plt.show()

# %%
m1=sns.distplot(movies.AudienceRating)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m1=sns.distplot(movies.AudienceRating)
plt.show()

# %%
sns.set_style('white')
n1 = plt.hist(movies.AudienceRating, bins=20)
plt.show()

# %%
n1 = plt.hist(movies.CriticRating, bins=20)
plt.show()

# %%
m2 = sns.distplot(movies.AudienceRating, bins = 15)
plt.show()

# %%
sns.set_style('white')
m3 = sns.distplot(movies.AudienceRating, bins = 20)
plt.show()

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
vis1 = sns.lmplot(data=movies , x='CriticRating' , y='AudienceRating', fit_reg=False)
plt.show()

# %%
plt.hist(movies[movies.Zoner == 'Drama'].BudgetMillions)
plt.show()

# %%
movies.head(20)
# Out:
#                                  Film      Zoner  CriticRating  \
# 0               (500) Days of Summer      Comedy            87
# 1                         10,000 B.C.  Adventure             9
# 2                          12 Rounds      Action            30
# 3                           127 Hours  Adventure            93
# 4                           17 Again      Comedy            55
# 5                                2012     Action            39
# 6                          27 Dresses     Comedy            40
# 7                    30 Days of Night     Horror            50
# 8                  30 Minutes or Less     Comedy            43
# 9                               50/50     Comedy            93
# 10                         88 Minutes      Drama             5
# 11                 A Dangerous Method      Drama            79
# 12          A Nightmare on Elm Street     Horror            13
# 13                     A Serious Man       Drama            89
# ...

# %%
movies.tail(20)
# Out:
#                                    Film      Zoner  CriticRating  \
# 539                        When in Rome     Comedy            15
# 540          Where the Wild Things Are   Adventure            73
# 541                            Whip It       Drama            84
# 542                           Whiteout      Action             7
# 543          Why Did I Get Married Too?     Comedy            27
# 544                           Wild Hogs     Comedy            14
# 545                       Winter's Bone      Drama            94
# 546           X-Men Origins: Wolverine      Action            37
# 547                  X-Men: First Class     Action            87
# 548                           Year One   Adventure            14
# 549                             Yes Man     Comedy            43
# 550                           Yogi Bear     Comedy            14
# 551                           You Again     Comedy            18
# ...

# %%
plt.hist(movies[movies.Zoner == 'Comedy'].BudgetMillions , bins = 20)
plt.hist(movies[movies.Zoner == 'Action'].BudgetMillions , bins = 20)
plt.hist(movies[movies.Zoner =='Drama'].BudgetMillions , bins = 20)
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Zoner == 'Comedy'].BudgetMillions,\
         movies[movies.Zoner == 'Action'].BudgetMillions,\
         movies[movies.Zoner == 'Drama'].BudgetMillions,\
         movies[movies.Zoner == 'Horror'].BudgetMillions],
         bins = 20,stacked = True)
plt.show()

# %%
for Zone in movies.Zoner.cat.categories:
    print(Zone)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movies , x='CriticRating' , y='AudienceRating', fit_reg=False)
plt.show()

# %%
vis1 = sns.lmplot(data=movies , x='CriticRating' , y='AudienceRating', fit_reg=True)
plt.show()

# %%
vis1 = sns.lmplot(data=movies , x='CriticRating' , y='AudienceRating', fit_reg=True,hue='Zoner')
plt.show()

# %%
vis1 = sns.lmplot(data=movies , x='CriticRating' , y='AudienceRating', fit_reg=False,hue='Zoner')
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating',y='AudienceRating',fit_reg=False, hue='Zoner',height=5,aspect=1)
plt.show()

# %%
k1 = sns.kdeplot(x=movies.CriticRating , y=movies.AudienceRating)
plt.show()

# %%
k1=sns.kdeplot(x=movies.CriticRating ,y=movies.AudienceRating , shade = True , shade_lowest = False , cmap = 'Reds')
plt.show()

# %%
k2 = sns.kdeplot(x=movies.CriticRating ,y=movies.AudienceRating,shade=False,shade_lowest=False,cmap='Greens')
plt.show()

# %%
sns.set_style('dark')
k2 = sns.kdeplot(x=movies.CriticRating ,y=movies.AudienceRating,shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,shade_lowest=True,cmap='Greens_r')
plt.show()

# %%
k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating)
plt.show()

# %%
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating)
plt.show()

# %%
f,ax=plt.subplots(1,2, figsize=(8,4))
plt.show()

# %%
f,axes=plt.subplots(1,2,figsize=(6,3))
k1=sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax=axes[1])
plt.show()

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
B=sns.boxplot(data=movies,x='Zoner',y='CriticRating')
plt.show()

# %%
B=sns.boxplot(data=movies, x='Zoner' , y='CriticRating',hue='Zoner')
plt.show()

# %%
vis5=sns.violinplot(data=movies,x='Zoner',y='CriticRating')
plt.show()

# %%
Z=sns.violinplot(data=movies,x='Zoner',y='CriticRating',hue='Zoner')
plt.show()

# %%
a1=sns.boxplot(data=movies[movies.Zoner == 'Drama'],x='Year',y='CriticRating',hue='Year',palette='deep')
plt.show()

# %%
z=sns.violinplot(data=movies[movies.Zoner=='Drama'],x='Year',y='CriticRating',hue='Year',palette='deep')
plt.show()

# %%
g=sns.FacetGrid(movies,row='Zoner',col='Year',hue='Zoner')
plt.show()

# %%
plt.scatter(x=movies.CriticRating,y=movies.AudienceRating)
plt.style.use('dark_background')
plt.show()

# %%
n=sns.FacetGrid(movies,row='Zoner',col='Year',hue='Zoner')
n=n.map(plt.scatter,'CriticRating','AudienceRating')
plt.show()

# %%
g=sns.FacetGrid(movies,row='Zoner',col='Year',hue='Zoner')
g=g.map(plt.hist,'BudgetMillions')
plt.show()

# %%
g=sns.FacetGrid(movies,row='Zoner',col='Year',hue='Zoner')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
plt.show()

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))
k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax = axes[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax = axes[0,1])
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
z = sns.violinplot(data=movies[movies.Zoner=='Drama'], x='Year', y = 'CriticRating',hue='Year',palette='deep',ax=axes[1,0])
k4 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
k4b = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,cmap='Reds',ax = axes[1,1])
plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))
k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating, \
                 shade = True, shade_lowest=True,cmap = 'Greens_r', \
                 ax = axes[0,0])
k1b = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating, \
                 cmap = 'cool',ax = axes[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,\
                  cmap = 'cool', ax = axes[0,1])
z = sns.violinplot(data=movies[movies.Zoner=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])
k4 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating, \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])
k4b = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating, \
                  cmap='gist_gray_r',ax = axes[1,1])
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()
