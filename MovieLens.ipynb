# %%
import pandas as pd

# %%
#reading the dataset

# %%
ratings = pd.read_csv(r'C:\Users\Neha\Downloads\archive\rating.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
tags = pd.read_csv(r'C:\Users\Neha\Downloads\archive\tag.csv')

# %%
tags.head(3)
# Out:
#    userId  movieId          tag            timestamp
# 0      18     4141  Mark Waters  2009-04-24 18:19:40
# 1      65      208    dark hero  2013-05-10 01:41:18
# 2      65      353    dark hero  2013-05-10 01:41:19

# %%
tags.shape
# Out:
# (465564, 4)

# %%
movies = pd.read_csv(r'C:\Users\Neha\Downloads\archive\movie.csv')

# %%
movies.head(4)
# Out:
#    movieId                     title  \
# 0        1          Toy Story (1995)
# 1        2            Jumanji (1995)
# 2        3   Grumpier Old Men (1995)
# 3        4  Waiting to Exhale (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance

# %%
movies.shape
# Out:
# (27278, 3)

# %%
print(tags.columns)
print(ratings.columns)
print(movies.columns)
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(tags.columns)
print(ratings.columns)
print(movies.columns)
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')
# Index(['userId', 'movieId', 'rating'], dtype='object')
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
tags.head(3)
# Out:
#    userId  movieId          tag
# 0      18     4141  Mark Waters
# 1      65      208    dark hero
# 2      65      353    dark hero

# %%
tags.head(4)
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller

# %%
row_1=tags.iloc[1]
row_1
# Out:
# userId            65
# movieId          208
# tag        dark hero
# Name: 1, dtype: object

# %%
row_0=tags.iloc[0]
row_0
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
row_0["userId"]
# Out:
# np.int64(18)

# %%
'rating' in row_0
# Out:
# False

# %%
'rating' in row_1
# Out:
# False

# %%
row_0.name
# Out:
# 0

# %%
row_1.name
# Out:
# 1

# %%
row_0=row_0.rename("FirstRow")
row_0.name
# Out:
# 'FirstRow'

# %%
row_1=row_1.rename("SecondRow")
row_1.name
# Out:
# 'SecondRow'

# %% [markdown]
# # DATA FRAMES

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.head(7)
# Out:
#    userId  movieId               tag
# 0      18     4141       Mark Waters
# 1      65      208         dark hero
# 2      65      353         dark hero
# 3      65      521     noir thriller
# 4      65      592         dark hero
# 5      65      668         bollywood
# 6      65      898  screwball comedy

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[0,11,500]]
# Out:
#      userId  movieId                tag
# 0        18     4141        Mark Waters
# 11       65     1783      noir thriller
# 500     342    55908  entirely dialogue

# %% [markdown]
# # Descriptive Statistics

# %%
ratings["rating"].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings['rating'].mean()
# Out:
# np.float64(3.5255285642993797)

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].count()
# Out:
# np.int64(20000263)

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings.min()
# Out:
# userId     1.0
# movieId    1.0
# rating     0.5
# dtype: float64

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.mode()
# Out:
#    userId  movieId  rating
# 0  118205      296     4.0

# %%
filter1 = ratings["rating"]>10
filter1
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool

# %% [markdown]
# # Data Cleaning : Handling Missing Data

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
ratings.isnull().sum()
# Out:
# userId     0
# movieId    0
# rating     0
# dtype: int64

# %%
tags.shape
# Out:
# (465564, 3)

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ratings.hist(column='rating',figsize=(10,5))
plt.show()

# %%
ratings.boxplot(column='rating' , figsize=(10,5))
plt.show()

# %% [markdown]
# # Slicing Out Columns

# %%
tags['tag'].head
# Out:
# <bound method NDFrame.head of 0           Mark Waters
# 1             dark hero
# 2             dark hero
# 3         noir thriller
# 4             dark hero
#               ...
# 465559          dragged
# 465560    Jason Bateman
# 465561           quirky
# 465562              sad
# 465563    rise to power
# Name: tag, Length: 465564, dtype: object>

# %%
tags['tag'].head(1)
# Out:
# 0    Mark Waters
# Name: tag, dtype: object

# %%
movies[['title','genres']].head(1)
# Out:
#               title                                       genres
# 0  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
movies[['title','genres']].head(3)
# Out:
#                      title                                       genres
# 0         Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1           Jumanji (1995)                   Adventure|Children|Fantasy
# 2  Grumpier Old Men (1995)                               Comedy|Romance

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]
# Out:
# tag
# Hell naw                      1
# This is my happy face         1
# I heel toe on Uday's house    1
# Why?                          1
# Bobo                          1
# Diamond Dallas Page           1
# I'm Devon Butler!             1
# No arguement                  1
# Really Bad                    1
# Botox                         1
# Name: count, dtype: int64

# %%
tag_counts.head(3)
# Out:
# tag
# sci-fi             3384
# based on a book    3281
# atmospheric        2917
# Name: count, dtype: int64

# %%
tag_counts.tail(3)
# Out:
# tag
# No arguement    1
# Really Bad      1
# Botox           1
# Name: count, dtype: int64

# %%
tag_counts[:10].plot(
kind="bar",
figsize=(10,5),
xlabel="Tags",
ylabel="Counts according to the tags",
color=["blue", "orange", "green", "red", "purple", "brown", "pink", "darkblue", "lightgreen"]
)
plt.show()
