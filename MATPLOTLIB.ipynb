# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x1=np.linspace(0,10,50)

# %%
plt.plot(x1 , np.sin(x1), '-')
plt.show()

# %%
plt.plot(x1, np.cos(x1),'--')
plt.show()

# %%
plt.plot(x1, np.tan(x1),'-.')
plt.show()

# %%
plt.plot(x1, np.sin(x1),'-')
plt.plot(x1, np.cos(x1),'--')
plt.plot(x1, np.tan(x1),'-.')
plt.show()

# %%
# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1), '*')
plt.show()

# %%
# create a plot figure
plt.figure()
plt.show()

# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.sin(x1))
plt.show()
# create the second of two panels and set current axis
plt.subplot(2, 1, 2)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1));
plt.show()

# %%
# get current figure information
print(plt.gcf())
plt.show()
# Out:
# Figure(640x480)

# %%
# get current axis information
print(plt.gca())
plt.show()
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ## Visulization with pyplot

# %%
plt.plot([1,2,3,4], [1,8,2,16])
plt.ylabel('Numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 8, 27, 64])
plt.show()

# %% [markdown]
# # State-Machine Interface

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# # Working with NumPy Arrays

# %%
t = np.arange(0., 5., 0.2) # evenly sampled time at 200ms intervals
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')# red dashes, blue squares and green triangles
plt.show()

# %% [markdown]
# # OBJECT-ORIENTED API

# %%
fig, ax = plt.subplots(2)
ax[0].plot(x1, np.sin(x1), 'b-')
ax[1].plot(x1, np.cos(x1), 'b-');
plt.show()

# %% [markdown]
# # Objects And Reference

# %%
fig = plt.figure()
x2 = np.linspace(0, 5, 10)
y2 = x2 ** 2
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x2, y2, 'r')
axes.set_xlabel('x2')
axes.set_ylabel('y2')
axes.set_title('title');
plt.show()

# %% [markdown]
# # Figure And Axes

# %%
fig = plt.figure()
ax = plt.axes()
plt.show()

# %% [markdown]
# # FIGURE AND SUBPLOTS

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)
plt.show()

# %% [markdown]
# # First Plot With Mathplotlib

# %%
plt.plot([1, 3, 2, 4], 'b-')
plt.show( )

# %%
x3 = range(6)          #Specify both Lists
plt.plot(x3, [xi**2 for xi in x3])
plt.show()

# %% [markdown]
# # MULTILINE PLOTS

# %%
x4 = range(1, 5)
plt.plot(x4, [xi*1.5 for xi in x4])
plt.plot(x4, [xi*3 for xi in x4])
plt.plot(x4, [xi/3.0 for xi in x4])
plt.show()

# %% [markdown]
# # SAVING THE PLOT

# %%
fig.savefig('plot2.png')               #Saving the figure

# %%
from IPython.display import Image      #Explore the contents of figure
Image('plot2.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# # LINE PLOT

# %%
fig = plt.figure()    ## Create figure and axes first
ax = plt.axes()
x5 = np.linspace(0, 10, 1000)   # Declare a variable x5
ax.plot(x5, np.sin(x5), 'b-');  # Plot the sinusoid function
plt.show()

# %% [markdown]
# # SCATTER PLOT

# %%
x7 = np.linspace(0, 10, 30)
y7 = np.sin(x7)
plt.plot(x7, y7, 'o', color = 'black'); #plt.plot() for scattering a plot
plt.show()

# %% [markdown]
# # HISTOGRAM

# %%
data1 = np.random.randn(1000)
plt.hist(data1); 
plt.show()

# %% [markdown]
# # BAR CHART

# %%
data2 = [5. , 25. , 50. , 20.]
plt.bar(range(len(data2)), data2)
plt.show()

# %% [markdown]
# # HORIZONTAL BAR CHART

# %%
data2 = [5. , 25. , 50. , 20.]
plt.barh(range(len(data2)), data2)
plt.show()

# %% [markdown]
# # ERROR BAR CHART

# %%
x9 = np.arange(0, 4, 0.2)
y9 = np.exp(-x9)
e1 = 0.1 * np.abs(np.random.randn(len(y9)))
plt.errorbar(x9, y9, yerr = e1, fmt = '.-')
plt.show()

# %% [markdown]
# # STACKED BAR CHART

# %%
A = [15., 30., 45., 22.]
B = [15., 25., 50., 20.]
z2 = range(4)
plt.bar(z2, A, color = 'b')
plt.bar(z2, B, color = 'r', bottom = A)
plt.show()

# %% [markdown]
# # PIE CHART

# %%
plt.figure(figsize=(7,7))
x10 = [35, 25, 20, 20]
labels = ['Computer', 'Electronics', 'Mechanical', 'Chemical']
plt.pie(x10, labels=labels);
plt.show()

# %% [markdown]
# # BOXPLOT

# %%
data3 = np.random.randn(100)
plt.boxplot(data3)
plt.show()

# %% [markdown]
# # AREA CHART

# %%
x12 = range(1, 6)          # Create some data
y12 = [1, 4, 6, 8, 4]
plt.fill_between(x12, y12)  # Area plot
plt.show()

# %% [markdown]
# # CONTOUR PLOT

# %%
matrix1 = np.random.rand(10, 20)     # Create a matrix
cp = plt.contour(matrix1)
plt.show()

# %% [markdown]
# # STYLES WITH MATPLOTLIB PLOTS

# %%
print(plt.style.available)         # View list of all available styles
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# # ADDING A GRID

# %%
x15 = np.arange(1, 5)
plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15/3.0)
plt.grid(True)
plt.show()

# %% [markdown]
# # HANDLING AXES

# %%
x15 = np.arange(1, 5)
plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15/3.0)
plt.axis()   # shows the current axis limits values
plt.axis([0, 5, -1, 13])
plt.show()

# %%
x15 = np.arange(1, 5)
plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15/3.0)
plt.xlim([1.0, 4.0])
plt.ylim([0.0, 12.0])
plt.show()

# %% [markdown]
# # HANDLING X AND Y TICKS

# %%
u = [5, 4, 9, 7, 8, 9, 6, 5, 7, 8]
plt.plot(u)
plt.xticks([2, 4, 6, 8, 10])
plt.yticks([2, 4, 6, 8, 10])
plt.show()

# %% [markdown]
# # ADDING LABELS

# %%
plt.plot([1, 3, 2, 4])
plt.title('First Plot')
plt.show()

# %% [markdown]
# # ADDING A LEGEND

# %%
x15 = np.arange(1, 5)
fig, ax = plt.subplots()
ax.plot(x15, x15*1.5)
ax.plot(x15, x15*3.0)
ax.plot(x15, x15/3.0)
ax.legend(['Normal','Fast','Slow'])
plt.show()

# %%
x15 = np.arange(1, 5)
fig, ax = plt.subplots()
ax.plot(x15, x15*1.5, label='Normal')
ax.plot(x15, x15*3.0, label='Fast')
ax.plot(x15, x15/3.0, label='Slow')
ax.legend()
plt.show()

# %% [markdown]
# # CONTROL COLOURS

# %%
x16 = np.arange(1, 5)
plt.plot(x16, 'r')
plt.plot(x16+1, 'g')
plt.plot(x16+2, 'b')
plt.show()

# %% [markdown]
# # CONTROL LINE STYLES

# %%
x16 = np.arange(1, 5)
plt.plot(x16, '--', x16+1, '-.', x16+2, ':')
plt.show()
